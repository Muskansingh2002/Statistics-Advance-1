# %% [markdown]
# Q1. What is the Probability density function?

# %% [markdown]
# Ans:
#
# A Probability Density Function (PDF) is a function that describes the likelihood of a continuous random variable taking on a particular value. In other words, the PDF provides the relative likelihood of different outcomes for a continuous random variable.

# %% [markdown]
# Q2. What are the types of Probability distribution?

# %% [markdown]
# Ans:
#
#  Probability distributions describe how the values of a random variable are distributed. There are two main types of probability distributions: discrete and continuous.
#
# Discrete Distributions: Focus on variables that take on specific, separate values. Examples include binomial, Poisson, and geometric distributions.
#
# Continuous Distributions: Focus on variables that take on any value within a continuous range. Examples include normal, exponential, and uniform distributions.

# %% [markdown]
# Q3. Write a Python function to calculate the probability density function of a normal distribution with
# given mean and standard deviation at a given point.

# %%
import math

def normal_pdf(x, mu, sigma):
   
    coefficient = 1 / (sigma * math.sqrt(2 * math.pi))
    exponent = -((x - mu) ** 2) / (2 * sigma ** 2)
    return coefficient * math.exp(exponent)

# Example usage:
x = 0
mu = 0
sigma = 1
pdf_value = normal_pdf(x, mu, sigma)
print(f"The value of the PDF at x = {x} for a normal distribution with mean {mu} and standard deviation {sigma} is {pdf_value:.6f}")
# Out:
# The value of the PDF at x = 0 for a normal distribution with mean 0 and standard deviation 1 is 0.398942

# %% [markdown]
# Q4. What are the properties of Binomial distribution? Give two examples of events where binomial
# distribution can be applied.

# %% [markdown]
# Ans:
#
# Properties of Binomial Distribution
#
# 1.Fixed Number of Trials (n): The number of trials, denoted as
# 𝑛
#
# n, is fixed and finite.
#
# 2.Two Possible Outcomes: Each trial results in one of two outcomes, often referred to as "success" and "failure."
#
# 3.Constant Probability of Success (p): The probability of success, denoted as
# 𝑝
#
# p, is the same for each trial. The probability of failure is
# 1−p.
#
# 4.Independence: Each trial is independent of the others. The outcome of one trial does not affect the outcome of another.
#
# 5.Random Variable (X): The random variable
# 𝑋
# X represents the number of successes in the
# n trials and can take on values from 0 to
# 𝑛.
#
# 6.Probability Mass Function (PMF): The probability of observing exactly k successes in n trials is given by the binomial formula:
#
# Examples of Events Where Binomial Distribution Can Be Applied
#
# 1.Quality Control in Manufacturing:
#
# Suppose a factory produces light bulbs, and each light bulb has a 95% chance of passing quality control (success). If a quality inspector randomly selects 10 light bulbs from the production line, the number of light bulbs that pass quality control can be modeled using a binomial distribution with
# n=10 and p=0.95.
#
# 2.Survey Responses:
#
# Consider a political survey where each respondent has a 60% chance of supporting a particular candidate (success). If the survey is conducted with 50 respondents, the number of respondents who support the candidate can be modeled using a binomial distribution with
# n=50 and p=0.60.

# %% [markdown]
# Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4
# and plot a histogram of the results using matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 10     
p = 0.4     
size = 1000 

sample = np.random.binomial(n, p, size)

plt.figure(figsize=(10, 6))
plt.hist(sample, bins=range(n+2), edgecolor='black', alpha=0.7)
plt.title('Histogram of Binomial Distribution Sample')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.xticks(range(n+1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution
# with given mean at a given point.

# %%
import math

def poisson_cdf(k, lam):
   
    cdf = 0.0
    for i in range(k + 1):
        cdf += (lam ** i) * math.exp(-lam) / math.factorial(i)
    return cdf

k = 5
lam = 3.0
cdf_value = poisson_cdf(k, lam)
print(f"The value of the CDF at k = {k} for a Poisson distribution with mean {lam} is {cdf_value:.6f}")
# Out:
# The value of the CDF at k = 5 for a Poisson distribution with mean 3.0 is 0.916082

# %% [markdown]
# Q7. How Binomial distribution different from Poisson distribution?

# %% [markdown]
# Ans:
# Binomial Distribution: Describes the number of successes in a fixed number of independent Bernoulli trials (each trial with the same probability of success).
#
# Poisson Distribution: Describes the number of events occurring in a fixed interval of time or space, where events occur with a constant mean rate and independently of the time since the last event.

# %% [markdown]
# Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the
# sample mean and variance.

# %%
import numpy as np

lambda_poisson = 5
sample_size = 1000

sample = np.random.poisson(lambda_poisson, sample_size)

sample_mean = np.mean(sample)
sample_variance = np.var(sample)

print(f"Sample Mean: {sample_mean}")
print(f"Sample Variance: {sample_variance}")
# Out:
# Sample Mean: 4.946
# Sample Variance: 4.823084000000001

# %% [markdown]
# Q9. How mean and variance are related in Binomial distribution and Poisson distribution?

# %% [markdown]
# Ans:
#
# In the Binomial distribution, the mean is n⋅p and the variance is n⋅p⋅(1−p). The variance depends on both the number of trials and the probability of success.
#
# In the Poisson distribution, both the mean and the variance are equal to λ. This unique property means that the average rate of occurrence directly determines the spread of the distribution.

# %% [markdown]
# Q10. In normal distribution with respect to mean position, where does the least frequent data appear?
